# %%
import pandas as pd

# %%
data=pd.read_csv('/content/drive/MyDrive/housing.csv')
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.drop_duplicates()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data.notnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0           True      True                True         True            True
# 1           True      True                True         True            True
# 2           True      True                True         True            True
# 3           True      True                True         True            True
# 4           True      True                True         True            True
# ...          ...       ...                 ...          ...             ...
# 20635       True      True                True         True            True
# 20636       True      True                True         True            True
# 20637       True      True                True         True            True
# 20638       True      True                True         True            True
# 20639       True      True                True         True            True
#
# ...

# %%
data.isnull().sum().sum()
# Out:
# 207

# %%
data2=data.fillna(value=0)
data2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data3=data.fillna(method='pad')
data3
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data4=data.fillna(method='bfill')
data4
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import numpy as np
from scipy import stats

# %%
data2.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
data2.drop(['longitude'],axis=1,inplace=True)
data2.columns
# Out:
# Index(['latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms',
#        'population', 'households', 'median_income', 'median_house_value',
#        'ocean_proximity'],
#       dtype='object')

# %%
Q1=data2.quantile(0.25)
Q3=data2.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# latitude                   3.78000
# housing_median_age        19.00000
# total_rooms             1700.25000
# total_bedrooms           351.25000
# population               938.00000
# households               325.00000
# median_income              2.17985
# median_house_value    145125.00000
# ocean_proximity                NaN
# dtype: float64

# %%
data2=data2[~((data2<(Q1-1.5*IQR))|(data2>(Q3+1.5*IQR))).any(axis=1)]
data2
# Out:
#        latitude  housing_median_age  total_rooms  total_bedrooms  population  \
# 2         37.85                52.0       1467.0           190.0       496.0
# 3         37.85                52.0       1274.0           235.0       558.0
# 4         37.85                52.0       1627.0           280.0       565.0
# 5         37.85                52.0        919.0           213.0       413.0
# 6         37.84                52.0       2535.0           489.0      1094.0
# ...         ...                 ...          ...             ...         ...
# 20635     39.48                25.0       1665.0           374.0       845.0
# 20636     39.49                18.0        697.0           150.0       356.0
# 20637     39.43                17.0       2254.0           485.0      1007.0
# 20638     39.43                18.0       1860.0           409.0       741.0
# 20639     39.37                16.0       2785.0           616.0      1387.0
#
# ...

# %%
data2.describe()
# Out:
#            latitude  housing_median_age   total_rooms  total_bedrooms  \
# count  17617.000000        17617.000000  17617.000000    17617.000000
# mean      35.696169           29.491287   2146.155191      441.245672
# std        2.166689           12.207925   1091.692297      224.712921
# min       32.540000            1.000000      2.000000        0.000000
# 25%       33.940000           19.000000   1375.000000      283.000000
# 50%       34.300000           30.000000   1979.000000      409.000000
# 75%       37.740000           38.000000   2785.000000      576.000000
# max       41.950000           52.000000   5694.000000     1169.000000
#
#          population    households  median_income  median_house_value  \
# count  17617.000000  17617.000000   17617.000000        17617.000000
# mean    1198.265085    417.034796       3.575385       187056.853948
# std      603.352556    205.726321       1.443509        93761.648447
# ...
